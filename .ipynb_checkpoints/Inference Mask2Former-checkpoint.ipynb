# %% [markdown]
# ## Semantische Segmentierung: Inference mit Mask2Former

# %% [markdown]
# Im Rahmen des AI Projektes habe ich mich mit der semantischen Segmentierung befasst. Dabei sind die universellen Modelle Mask2Former sowie MaskFormer verwendet worden. Diese Modelle können drei unterschiedliche Aufgaben erledigen:
# - Instance Segmentierung
# - Semantische Segmentierung
# - Panoptische Segmentierung
#
# Der Fokus in diesem Individualprojekt liegt dabei auf der semantischen Segmentierung. Trotzdem ist im Rahmen des Projektes das Infernece mit panoptischer Semgentierung angeschaut worden, die Ergebnisse sind im Notebook "Panoptische Segmentierung: Inference Mask2Former" zu finden.

# %%
# Transformers wird direkt von HuggingFace installiert

# !pip install -q git+https://github.com/huggingface/transformers.git

# %%
# Benötigte Bibliotheken importieren

import requests
import os
import torch
from torchvision import transforms
from PIL import Image
from transformers import AutoImageProcessor, Mask2FormerForUniversalSegmentation

# %% [markdown]
# ### Modell importieren

# %%
from transformers import AutoImageProcessor, Mask2FormerForUniversalSegmentation

# Hierzu wird ein semantisches Segmentierungsmodell verwendet
# Dieses wurde bereits pretrained auf dem Cityscapes Datenset

processor = AutoImageProcessor.from_pretrained("facebook/mask2former-swin-small-cityscapes-semantic")
model = Mask2FormerForUniversalSegmentation.from_pretrained("facebook/mask2former-swin-small-cityscapes-semantic")
# Out:
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.48, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# /opt/conda/lib/python3.11/site-packages/transformers/utils/deprecation.py:165: UserWarning: The following named arguments are not valid for `Mask2FormerImageProcessor.__init__` and were ignored: '_max_size'
#   return func(*args, **kwargs)

# %% [markdown]
# ### Inference: COCO-Dataset

# %%
from PIL import Image
import requests

# Das Bild stammt aus dem Datensatz COCO
# Heruntergeladen über HuggingFace: detection-datasets/coco

image_path = "strassenszene_cityscapes.png"  
image = Image.open(image_path)
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=676x338>

# %%
# Bild für das Modell vorbereiten

inputs = processor(images=image, return_tensors="pt")
for k,v in inputs.items():
  print(k,v.shape)
# Out:
# pixel_values torch.Size([1, 3, 384, 384])
# pixel_mask torch.Size([1, 384, 384])

# %%
import torch

# Inferenz durchführen
# Es kann torch.no_grad() verwendet werden, da keine Gradienten berechnet werden müssen
# Dies spart Speicher und Rechenzeit

with torch.no_grad():
  outputs = model(**inputs)

# %%
# Ergebnisse anzeigen

predicted_map = processor.post_process_semantic_segmentation(outputs, target_sizes=[image.size[::-1]])[0]
print(predicted_map.shape)
# Out:
# torch.Size([338, 676])

# %%
import numpy as np

# Farbpallete erstellen

color_palette = [list(np.random.choice(range(256), size=3)) for _ in range(len(model.config.id2label))]
print(color_palette)
# Out:
# [[123, 54, 47], [3, 82, 161], [39, 71, 185], [12, 198, 40], [95, 125, 200], [251, 32, 243], [145, 5, 46], [104, 94, 39], [188, 12, 65], [62, 246, 73], [216, 96, 236], [143, 135, 254], [177, 96, 146], [160, 250, 56], [181, 153, 215], [16, 73, 69], [27, 209, 113], [222, 113, 138], [208, 190, 123]]

# %%
from torch import nn
import matplotlib.pyplot as plt

seg = predicted_map
color_seg = np.zeros((seg.shape[0], seg.shape[1], 3), dtype=np.uint8) # height, width, 3
palette = np.array(color_palette)
for label, color in enumerate(palette):
    color_seg[seg == label, :] = color
    
# Nach BGR konvertieren
color_seg = color_seg[..., ::-1]

# Bild + Maske anzeigen 
img = np.array(image) * 0.5 + color_seg * 0.5
img = img.astype(np.uint8)

plt.figure(figsize=(15, 10))
plt.imshow(img)
plt.show()

# %% [markdown]
# ### Ergebnisse:
#
# - Klassenunterscheidung: Die semantische Segmentierung trennt die Klassen wie Strasse, Fahrzeug (LKW sowie PW), Gebäude, Himmel etc. farblich deutlich.
#
# - Segmentierungsqualität: Die Strasse und Fahrzeuge wurden sauber extrahiert, einschliesslich teilweise verdeckter Objekte wie des LKWs.
#
# - Grenzübergänge: Die Übergänge zwischen Objekten (z. B. Gebäude und Himmel) sind grösstenteils sauber.
#
# Leider fehlen bei diesem Bild Ground Truth-Daten. Deshalb ist eine quantitative Bewertung der Segmentierung ohne Ground Truth nicht möglich, jedoch erscheint die visuelle Qualität des Ergebnisses plausibel.

# %% [markdown]
# ### Inference: Mapillary Vista
#
# Es wird ein zweites Inference erstellt. Dieses Mal mit einem Bild aus dem Datenset Mapillary Vista. Dies da Bilder aus dem Datensatz Mapillary Vista dieses vortrainierten Modells Mask2Former mit dem selbst trainierten Modell MaskFormer verglichen werden sollen. Dabei versuchen wir einmal ein Bild mit Menschen reinzuladen um zu sehen, wie gut Personen erkennt werden können.

# %%
# Das Bild stammt aus dem Datensatz Mapillary Vista
# Heruntergeladen über HuggingFace: moritzef/mapillary_vistas_semantic_edges_and_segmentation

image_path = "strassenszene mit menschen.jpg"  
image2 = Image.open(image_path)
image2
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=400x300>

# %%
inputs = processor(images=image2, return_tensors="pt")
for k,v in inputs.items():
  print(k,v.shape)
# Out:
# pixel_values torch.Size([1, 3, 384, 384])
# pixel_mask torch.Size([1, 384, 384])

# %%
with torch.no_grad():
  outputs = model(**inputs)

# %%
predicted_map = processor.post_process_semantic_segmentation(outputs, target_sizes=[image2.size[::-1]])[0]
print(predicted_map.shape)
# Out:
# torch.Size([300, 400])

# %%
seg = predicted_map
color_seg = np.zeros((seg.shape[0], seg.shape[1], 3), dtype=np.uint8) # height, width, 3
palette = np.array(color_palette)
for label, color in enumerate(palette):
    color_seg[seg == label, :] = color
# Convert to BGR
color_seg = color_seg[..., ::-1]

# Show image + mask
img = np.array(image2) * 0.5 + color_seg * 0.5
img = img.astype(np.uint8)

plt.figure(figsize=(15, 10))
plt.imshow(img)
plt.show()

# %% [markdown]
# ### Ergebnisse:
#
# Objekttrennung:
# - Die unterschiedlichen Objekte (z. B. Personen, Strasse, Gebäude) sind grundsätzlich sauber voneinander getrennt worden.
# - Details: Feine Details wie die Silhouetten der Personen und Gegenstände wurden erfasst.
#
# Verbesserungsbedarf:
# - Genauigkeit der Grenzen: An manchen Stellen (z. B. bei den Personen) könnten die Grenzen schärfer und präziser sein.
# - Objekte mit geringer Auflösung: Kleinere Objekte, wie Details in den Personen oder Objekte in der Ferne, könnten besser erkannt werden.
#
# Fazit:
# Das Modell scheint die unterschiedlichen Klassen gut zu erkennen. Das Bild des Datensatzes Mapillary Vista könnte noch klarere Grenzen aufweisen. Dies könnte jedoch auch mit der leichten Unschärfe des Bildes zusammenhängen.

# %%
image_path = "verkehrssituation_mapillary_vista.jpg"  
image3 = Image.open(image_path)
image3
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=400x300>

# %%
inputs = processor(images=image3, return_tensors="pt")
for k,v in inputs.items():
  print(k,v.shape)
# Out:
# pixel_values torch.Size([1, 3, 384, 384])
# pixel_mask torch.Size([1, 384, 384])

# %%
with torch.no_grad():
  outputs = model(**inputs)

# %%
predicted_map = processor.post_process_semantic_segmentation(outputs, target_sizes=[image3.size[::-1]])[0]
print(predicted_map.shape)
# Out:
# torch.Size([300, 400])

# %%
seg = predicted_map
color_seg = np.zeros((seg.shape[0], seg.shape[1], 3), dtype=np.uint8) # height, width, 3
palette = np.array(color_palette)
for label, color in enumerate(palette):
    color_seg[seg == label, :] = color
# Convert to BGR
color_seg = color_seg[..., ::-1]

# Show image + mask
img = np.array(image3) * 0.5 + color_seg * 0.5
img = img.astype(np.uint8)

plt.figure(figsize=(15, 10))
plt.imshow(img)
plt.show()
